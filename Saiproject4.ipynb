# %% [markdown]
# # DAV 5400 Project 4
# #### Sai Krishna Dadi

# %% [markdown]
# # Introduction:
# Electric vehicles (EVs) have arisen as a revolutionary technology in the automotive industry, providing a greener and more sustainable option to standard gasoline-powered vehicles. The corpus accessible comprises an abundance of illuminating information regarding individual electric vehicles, encompassing minutiae such as Vehicle Identification Number (VIN), geographical location, model specifications, and Clean Alternative Fuel Vehicle (CAFV) eligibility. Such an encyclopedia has profound implications for thorough scrutiny and perusal.
# ## Research Question:
# The fundamental query that lies at the crux of this research venture is to explicate the intricate and subtle patterns and characteristic traits of electrified vehicles. To delve deep into this matter, a barrage of specific inquiries must be addressed holistically. These include investigating and comprehending the geographical distributional dynamics surrounding EVs, exploring variances in electric range amidst diverse categories of these cars, reflecting on how legislative districts impact their adoption rates, and scrutinizing various manufacturers' influence on the EV market with different models offered in it.

# %% [markdown]
# # Data Summary:
#
# ## Data Source
# It is imperative to comprehend the origins of the dataset at hand comprehensively. Upon due diligence, one may reason that it likely stems from a plethora of sources, including but not limited to automotive industry databases and government records. Furthermore, some have posited that crowd-sourced data contribution was also employed in forming this amalgamated cohort of information. By unearthing the provenance details, we thereby ascertain its veracity and all-encompassing nature, deeming it reliable for our purposes moving forward.
# ### Use Cases
# * It is of paramount importance for policymakers to maximize the analytical potential of datasets when formulating specific policies that aim to promote Electric Vehicle (EV) adoption in particular regions.
# * With that being said, an astute approach would be for automotive manufacturers to peruse this dataset with a fine-tooth comb in order to ascertain notable market trends and, more importantly, consumer preferences so as to gain insights into futuristic production strategies.
# * Alternatively, else, environmental organizations can thoroughly evaluate this road map, epitomizing information about EVs vis-a-vis quantifying the positive impact on mitigating carbon emissions on earth's climate patterns, which will inevitably aid them in strategizing realistic contingency plans for ecology reforms.
# ### Attributes
# The dataset set before us encompasses a multitude of variables that are both diverse and heterogeneous. These attributes range from alphanumeric designations such as the ever-iconic VIN to more spatially-oriented measurements like geographical coordinates, all while including specifications related to transportation such as electric range and CAFV eligibility. Truly an amalgamation of complex systems converging under one overarching construct - each attribute adding another layer of depth to this seemingly insurmountable task ahead.
# ### Data Types
# The corpus under consideration comprises manifold data forms, encompassing alphanumeric characters in the form of vehicular identification numbers (VIN). These categorical variables may consist of state, county, and city level statistics, numerical types like electric range and base MSRP amounts, as well as geospatial references that indicate vehicle location. This copious collection hinges upon one key assumption that are comprehending this amalgamated dataset requires expert handling. The crux lies in extracting meaningful insights anchored strongly in evidentiary analysis by navigating through these distinct data streams with great acumen, ensuring no dilution or loss en route.

# %%
import pandas as pd
from modeling_packages.DataSummary import DataSummary
from modeling_packages.EDA import ExploratoryDataAnalysis
from modeling_packages.predictive_model import PredictiveModeling
df = pd.read_csv('https://raw.githubusercontent.com/saidadi/codingscripts/main/sai/Electric_Vehicle_Population_Data%20(3).csv')

# %%
data_summary = DataSummary(df)
print(data_summary.basic_info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153830 entries, 0 to 153829
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         153830 non-null  object
#  1   County                                             153827 non-null  object
#  2   City                                               153827 non-null  object
#  3   State                                              153830 non-null  object
#  4   Postal Code                                        153827 non-null  float64
#  5   Model Year                                         153830 non-null  int64
#  6   Make                                               153830 non-null  object
#  7   Model                                              153830 non-null  object
# ...

# %%
print(data_summary.missing_values())
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 339
# DOL Vehicle ID                                         0
# Vehicle Location                                       7
# Electric Utility                                       3
# ...

# %%
print(data_summary.summary_statistics())
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  153827.000000  153830.000000   153830.000000  153830.000000
# mean    98171.496226    2020.100780       65.727673    1273.032276
# std      2437.224154       3.019617       95.147219    9086.044139
# min      1730.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2018.000000        0.000000       0.000000
# 50%     98122.000000    2021.000000       17.000000       0.000000
# 75%     98370.000000    2023.000000       84.000000       0.000000
# max     99577.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         153491.000000    1.538300e+05       1.538270e+05
# mean              29.302558    2.124161e+08       5.297335e+10
# std               14.828506    8.054800e+07       1.620212e+09
# min                1.000000    4.385000e+03       1.081042e+09
# ...

# %% [markdown]
# # Exploratory Data Analysis:
# Exploratory Data Analysis (EDA) unquestionably represents an indispensable facet of the data analysis process. Akin to a compass that guides wandering sailors through vast oceans, EDA aids data analysts in traversing voluminous datasets by effectively illuminating key characteristics of the dataset at hand. In no uncertain terms, this helps gain valuable insights into underlying distributions and trends, ultimately enabling analysts to glean intricate relationships nestled within complex data matrices.
# ### Summary Statistics:
# In the realm of statistical analysis, one valuable tool is summary statistics. This magical function affords individuals a comprehensive snapshot that encapsulates key insights into central tendencies, as well as variations in numerical attributes. However, how exactly does this wizardry work? To better understand its inner workings, let us take a closer inspection at some EDA code.
#
# The sumptuous summary_statistics method harnesses the awe-inspiring might of the describe function. Through its mystical incantations, it can reveal intricate tidbits like mean values, standard deviations, and percentiles for every single solitary numerical column present within our gloriously sensational dataset. Truly an impressive feat worth sporting about.
# ### Graphical Representation:
# Graphical representations provide visual insights into the data. The code includes:
#
# * **Distribution Plot**:
#   Utilizing the intricacies of exploratory data analysis, a distribution plot can be constructed to visualize the range of electric vehicles.
#
# * **Scatter Plot:**
#   The compelling and intellectually engaging concept that is most prevalent revolves around eda.scatter_plot(). This function allows for a robust data visualization tool, where one can unfurl insights about potential correlations or patterns between Electric Range and BaseMSRP.
#
# * **Geographical Distribution:**
#   The function eda.geographical_distribution() is a deeply insightful tool that illuminates the intricate geographical distribution of electric vehicles.
# * **Correlation Heatmap:**
#  In pursuit of an impeccable heatmap visualization, the analyses have yielded tremendous insight into the striking correlation matrix that exists between a myriad of numerical variables.
#
# The conglomeration of visualizations at our disposal offers an enticingly enriching prospect of augmenting our grasp over the structured patterns ingrained within a dataset.

# %%
eda = ExploratoryDataAnalysis(df)
eda.distribution_plot('Electric Range')

# %%
eda.scatter_plot('Electric Range', 'Base MSRP')

# %%
eda.geographical_distribution()

# %%
eda.correlation_heatmap()
# Out:
# /content/modeling_packages/EDA.py:85: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = self.data.corr()

# %% [markdown]
# # Predictive Modeling:
#
# ## Research Question:
# Can we predict the Clean Alternative Fuel Vehicle (CAFV) eligibility of an electric vehicle based on its attributes?
#
# ## Analysis
# * Data Preprocessing:
#
#   The method dubbed "preprocess_data" takes on several critical tasks, namely, grappling with the void left behind by missing values, executing categorical variable encoding, and, all in all, getting all the ducks in a row for model training.
# * Model Training:
#
#   In the task of constructing a model capable of accurately predicting future observations, the train_model method plays a pivotal role. This imperative function facilitates the training process by utilizing a RandomForestClassifier algorithm on meticulously preprocessed data, eventually churning out a well-rounded and effective predictive model.
# * Results:
#
#   * The measurement of the accuracy score is a fundamental validator in determining how well a model can predict CAFV eligibility.
#
#   * An observation of model performance across different classes is facilitated via an in-depth depiction of true positive, false positive, true negative and false negative predictions through the confusion matrix.
#
# Upon rigorous analysis of the available data, it can be inferred that by deploying provided attributes, one might potentially prognosticate whether an electric vehicle possesses the desirable qualifications necessary to possess a Clean Alternative Fuel Vehicle status.

# %%
positive_class_label = 1
predictive_modeling = PredictiveModeling(df)

# %%
predictive_modeling.preprocess_data()

# %%
accuracy, confusion_matrix, probas, y_test = predictive_modeling.train_model('Clean Alternative Fuel Vehicle (CAFV) Eligibility', positive_class_label)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 1.0

# %%
print(f'Confusion Matrix:\n{confusion_matrix}')
# Out:
# Confusion Matrix:
# [[16398     0]
#  [    0 14368]]

# %%
predictive_modeling.plot_confusion_matrix(confusion_matrix)

# %%
predictive_modeling.plot_roc_curve(y_test, probas)

# %% [markdown]
# ## Aggregation
# The class called "Aggregator" that imports the pandas, matplotlib. pyplot, and seaborn libraries. The constructor of this class reads Electric_Vehicle_Population_Data.csv from an online GitHub repository using Pandas library's read_csv method.
#
# This Aggregator class has two methods: aggregate_data() and plot_aggregated_data(). The first method (aggregate_data()) aggregates data based on certain columns ('State' and 'Make'), calculating the mean value for the 'Electric Range' column and the total sum for the 'Base MSRP' column. More aggregation could be added as required by modifying the agg() function call in lines 12-13. Finally, it returns a new Pandas DataFrame object with summarized aggregated information about electric vehicles.
#
# The second method (plot_aggregated_data()) plots bar graphs using Seaborn and Matplotlib libraries to visualize two sets of aggregated data - namely State-wise Base MRSP for each car chosen grouped into specifically colored clusters per Car Maker defined uniquely by their names extracted from aggregating such dataset composed simultaneously indicating frequencies around both selected fields aforementioned previously in average standards.

# %%
from modeling_packages import Aggregator
Aggregator.Aggregator().aggregate_data()
# Out:
#     State                  Make  Electric Range  Base MSRP
# 0      AK                 TESLA        0.000000          0
# 1      AL             CHEVROLET        0.000000          0
# 2      AL                 TESLA      110.000000          0
# 3      AP                NISSAN       75.000000          0
# 4      AR                NISSAN      150.000000          0
# ..    ...                   ...             ...        ...
# 188    WA                TOYOTA       27.109142          0
# 189    WA            VOLKSWAGEN       27.213576          0
# 190    WA                 VOLVO       15.700109   16829300
# 191    WA  WHEEGO ELECTRIC CARS      100.000000      98985
# 192    WY                   BMW        0.000000          0
#
# [193 rows x 4 columns]

# %%
Aggregator.Aggregator().plot_aggregated_data()

# %% [markdown]
# ## Grouping
# There utilizes the pandas and matplotlib. plot, and seabm thatorn libraries to group and visualize data related to electric vehicle populations.
#
# Three libraries are imported using the import statement; these include pandas (PD) and matplotlib. pyplot (plt) and seaborn (sns). These packages will be used for reading CSV files into a DataFrame object ("self.df"), grouping data based on specified criteria, and plotting grouped data.
#
# A class named "Grouper" is declared with an "init" function that reads in Electric Vehicle population data from GitHub's repository as CSV format ('Electric_Vehicle_Population_Data%20(3).csv') into "self.df".
#
# The "group_data()" method creates groups of electric vehicles by year along the axes at both 'Model Year ' and' Electric Vehicle Type.' The number of rows within each group is then calculated using ".size()," which converts this information as columns matching those in self. df. Finally, reset_index() is called to change summary stats back to individual columns: name='Count' ensures that the column created will have header name=Count
#
# Lastly,"plot_grouped_data()" becomes part of the Class; it generates visualizations after summarizing or processing given values. It leverages results from performed/aggregated earlier via .groupby & size(). Further modification can occur, such as setting x-axis labels(size(), years involved(model year)). With these parameters appropriately set, sns. Barplot helps us plot out differences between Electronic Vehicles per Model Year by their type(helpful for inference generation/analysis).

# %%
from modeling_packages import Grouper
Grouper.Grouper().group_data()
# Out:
#     Model Year                   Electric Vehicle Type  Count
# 0         1997          Battery Electric Vehicle (BEV)      1
# 1         1998          Battery Electric Vehicle (BEV)      1
# 2         1999          Battery Electric Vehicle (BEV)      3
# 3         2000          Battery Electric Vehicle (BEV)      8
# 4         2002          Battery Electric Vehicle (BEV)      2
# 5         2003          Battery Electric Vehicle (BEV)      1
# 6         2008          Battery Electric Vehicle (BEV)     20
# 7         2010          Battery Electric Vehicle (BEV)     21
# 8         2010  Plug-in Hybrid Electric Vehicle (PHEV)      3
# 9         2011          Battery Electric Vehicle (BEV)    710
# 10        2011  Plug-in Hybrid Electric Vehicle (PHEV)     79
# 11        2012          Battery Electric Vehicle (BEV)    781
# 12        2012  Plug-in Hybrid Electric Vehicle (PHEV)    868
# 13        2013          Battery Electric Vehicle (BEV)   2919
# ...

# %%
Grouper.Grouper().plot_grouped_data()

# %% [markdown]
# ## Reshaping
# The class called "Reshaper," which contains four methods for reshaping and visualizing data using the pandas, matplotlib. pyplot, and seaborn libraries. The init method reads in CSV data from an online repository.
#
# The first three methods reshape the original data frame into different formats using various pandas functions such as pivot_table(), melt(), and stack(). These methods return new data frames based on the operations. The three more methods that create visualizations of this reshaped data one with a stacked bar plot showing electric range by model across all states; another is a barplot that shows both electric range and base MSRP organized by make; finally, there is also a line plot for variables separated by make overtime periods defined in VIN (1-10), Model Year All plots are displayed inline after running each respective function

# %%
from modeling_packages import Reshaper
reshaped_pivot = Reshaper.Reshaper().reshape_data_with_pivot()
print("Reshaped with Pivot:")
print(reshaped_pivot)
# Out:
# Reshaped with Pivot:
#        VIN (1-10) Model Year        Make     Model Base MSRP                 \
# State                                                     AK AL AP AR AZ BC
# 0      1C4JJXN60P       2023        JEEP  WRANGLER         0  0  0  0  0  0
# 1      1C4JJXN61P       2023        JEEP  WRANGLER         0  0  0  0  0  0
# 2      1C4JJXN62P       2023        JEEP  WRANGLER         0  0  0  0  0  0
# 3      1C4JJXN63P       2023        JEEP  WRANGLER         0  0  0  0  0  0
# 4      1C4JJXN64P       2023        JEEP  WRANGLER         0  0  0  0  0  0
# ...           ...        ...         ...       ...       ... .. .. .. .. ..
# 9666   ZASPATDW2R       2024  ALFA ROMEO    TONALE         0  0  0  0  0  0
# 9667   ZASPATDW3R       2024  ALFA ROMEO    TONALE         0  0  0  0  0  0
# 9668   ZASPATDW5R       2024  ALFA ROMEO    TONALE         0  0  0  0  0  0
# 9669   ZASPATDW7R       2024  ALFA ROMEO    TONALE         0  0  0  0  0  0
# ...

# %%
Reshaper.Reshaper().reshape_data_with_pivot_plot()

# %%
reshaped_melt = Reshaper.Reshaper().reshape_data_with_melt()
print("\nReshaped with Melt:")
print(reshaped_melt)
# Out:
# Reshaped with Melt:
#         VIN (1-10)  Model Year       Make           Model          Metric  \
# 0       5UXTA6C05P        2023        BMW              X5  Electric Range
# 1       5YJRE11B48        2008      TESLA        ROADSTER  Electric Range
# 2       5YJSA1E24G        2016      TESLA         MODEL S  Electric Range
# 3       1N4AZ1CP5J        2018     NISSAN            LEAF  Electric Range
# 4       5YJ3E1EA6J        2018      TESLA         MODEL 3  Electric Range
# ...            ...         ...        ...             ...             ...
# 307655  1N4AZ0CP0D        2013     NISSAN            LEAF       Base MSRP
# 307656  5YJSA1E27H        2017      TESLA         MODEL S       Base MSRP
# 307657  1G1FW6S03P        2023  CHEVROLET         BOLT EV       Base MSRP
# 307658  3FMTK3SU1M        2021       FORD  MUSTANG MACH-E       Base MSRP
# 307659  1N4AZ0CP0D        2013     NISSAN            LEAF       Base MSRP
#
#         Value
# 0          30
# 1         220
# ...

# %%
Reshaper.Reshaper().reshape_data_with_melt_plot()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
reshaped_stack = Reshaper.Reshaper().reshape_data_with_stack()
print("\nReshaped with Stack:")
print(reshaped_stack)
# Out:
# Reshaped with Stack:
#          VIN (1-10)  Model Year    Make Model               Variable  \
# 0        5UXTA6C05P        2023     BMW    X5                 County
# 1        5UXTA6C05P        2023     BMW    X5                   City
# 2        5UXTA6C05P        2023     BMW    X5                  State
# 3        5UXTA6C05P        2023     BMW    X5            Postal Code
# 4        5UXTA6C05P        2023     BMW    X5  Electric Vehicle Type
# ...             ...         ...     ...   ...                    ...
# 1999424  1N4AZ0CP0D        2013  NISSAN  LEAF   Legislative District
# 1999425  1N4AZ0CP0D        2013  NISSAN  LEAF         DOL Vehicle ID
# 1999426  1N4AZ0CP0D        2013  NISSAN  LEAF       Vehicle Location
# 1999427  1N4AZ0CP0D        2013  NISSAN  LEAF       Electric Utility
# 1999428  1N4AZ0CP0D        2013  NISSAN  LEAF      2020 Census Tract
#
#                                                      Value
# ...

# %%
Reshaper.Reshaper().reshape_data_with_stack_plot()

# %% [markdown]
# # Conclusion:
# The electric vehicle industry is booming, and with that growth comes the exciting opportunity to gather data on their usage. This dataset offers a comprehensive overview of EV distribution, characteristics, and adoption trends that could revolutionize how we view sustainable transportation. By conducting rigorous analysis and predictive modeling, stakeholders can obtain invaluable insights into what factors influence EV adoption rates, information that may prove vital in making informed predictions regarding CAFV eligibility. Policymakers, manufacturers, and environmental advocates are champing at the bit for these findings as they guide them toward designing innovative solutions geared toward shaping a sustainable future for our planet's transportation sector.

# %% [markdown]
# # References
# Amara-Ouali, Y., Goude, Y., Massart, P., Poggi, J. M., & Yan, H. (2021). A review of electric vehicle load open data and models. Energies, 14(8), 2233.
#
#
# Calearo, L., Marinelli, M., & Ziras, C. (2021). A review of data sources for electric vehicle integration studies. Renewable and Sustainable Energy Reviews, 151, 111518.
#
#
# Oh, G., Leblanc, D. J., & Peng, H. (2020). Vehicle energy dataset (VED), a large-scale dataset for vehicle energy consumption research. IEEE Transactions on Intelligent Transportation Systems, 23(4), 3302-3312.
